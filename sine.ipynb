# %% [markdown]
# <a href="https://colab.research.google.com/github/SaidSainz/demo/blob/main/sine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

np.sin(np.pi)
# Out:
# np.float64(1.2246467991473532e-16)

# %%
from scipy import linalg
from scipy.linalg import hilbert
from scipy.linalg import norm
from scipy.sparse import identity
import numpy as np

n = 15 # Set the matrix dimension

# Create a Hilbert matrix
H  = hilbert(n)
Id = np.dot(H, linalg.inv(H))


# Compare using the Frobenius norm
norm(Id - identity(n))
# Out:
# np.float64(156.0743279226193)
